# %%
#Setup
import hvplot.pandas
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
cc_data=pd.read_csv("cc_data.csv")
cc_data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time       category     amt         city state  \
# 0      471033   2020-08-16 23:34:52      kids_pets   31.93      Shields    ND
# 1       35353   2019-04-08 21:18:33           home   11.59    Daly City    CA
# 2      391141   2020-07-13 05:47:18    food_dining   37.97       Bailey    NC
# 3      369533   2020-07-04 03:59:39  gas_transport   58.38  Whaleyville    MD
# 4      767951   2020-12-25 03:43:30    grocery_pos  107.58        Utica    PA
#
#        lat      long  city_pop         dob  merch_lat  merch_long gender
# 0  46.1838 -101.2589        77  1989-12-17  45.455940 -100.470589      F
# 1  37.6787 -122.4780    107941  1991-10-04  36.716307 -122.974625    NaN
# 2  35.8072  -78.0892      6629  1962-08-13  36.530192  -78.072629      F
# 3  38.4121  -75.2811       718  1985-03-19  39.172607  -75.400129      F
# 4  41.4798  -79.9403      1102  1989-07-08  41.149434  -80.700821      M

# %%
cc_data["state"].nunique()
# Out:
# 50

# %%
cc_data[['trans_date', 'trans_time']] = cc_data['trans_date_trans_time'].str.split(' ', n=1, expand=True)
cc_data[["hour","min:sec"]]=cc_data["trans_time"].str.split(":",n=1,expand=True)
cc_data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time       category     amt         city state  \
# 0      471033   2020-08-16 23:34:52      kids_pets   31.93      Shields    ND
# 1       35353   2019-04-08 21:18:33           home   11.59    Daly City    CA
# 2      391141   2020-07-13 05:47:18    food_dining   37.97       Bailey    NC
# 3      369533   2020-07-04 03:59:39  gas_transport   58.38  Whaleyville    MD
# 4      767951   2020-12-25 03:43:30    grocery_pos  107.58        Utica    PA
#
#        lat      long  city_pop         dob  merch_lat  merch_long gender  \
# 0  46.1838 -101.2589        77  1989-12-17  45.455940 -100.470589      F
# 1  37.6787 -122.4780    107941  1991-10-04  36.716307 -122.974625    NaN
# 2  35.8072  -78.0892      6629  1962-08-13  36.530192  -78.072629      F
# 3  38.4121  -75.2811       718  1985-03-19  39.172607  -75.400129      F
# 4  41.4798  -79.9403      1102  1989-07-08  41.149434  -80.700821      M
#
#    trans_date trans_time hour min:sec
# 0  2020-08-16   23:34:52   23   34:52
# 1  2019-04-08   21:18:33   21   18:33
# 2  2020-07-13   05:47:18   05   47:18
# 3  2020-07-04   03:59:39   03   59:39
# 4  2020-12-25   03:43:30   03   43:30

# %%
# Group by 'Trans Month' and count the number of fraud transactions in each month
fraud_by_tod = cc_data.groupby('hour').size()
fraud_by_tod=pd.DataFrame(fraud_by_tod)

title = "Fraud Transactions Breakdown by Time of Day"
# Create a bar graph
fraud_by_tod.plot(kind='bar', color='red', alpha=0.7)
plt.title(title)
plt.xlabel('Tiem of Day')
plt.ylabel('Number of Fraud Transactions')
plt.xticks(rotation=0)  # Rotate x-axis labels for better visibility
plt.savefig("TOD_breakdown.png")
plt.show()

# %%
cc_data.count()
# Out:
# Unnamed: 0               10000
# trans_date_trans_time    10000
# category                 10000
# amt                      10000
# city                     10000
# state                    10000
# lat                      10000
# long                     10000
# city_pop                 10000
# dob                      10000
# merch_lat                10000
# merch_long               10000
# gender                    7040
# trans_date               10000
# trans_time               10000
# hour                     10000
# min:sec                  10000
# dtype: int64

# %%
category_sum=cc_data.groupby('category')["amt"].sum()
category_df=pd.DataFrame(category_sum)
category_df
# Out:
#                       amt
# category
# entertainment    42033.98
# food_dining      36341.67
# gas_transport    65157.35
# grocery_net      20421.28
# grocery_pos     111665.06
# health_fitness   34996.80
# home             55475.03
# kids_pets        49175.87
# misc_net         40161.54
# misc_pos         45945.65
# personal_care    32030.73
# shopping_net     61141.89
# shopping_pos     61930.56
# travel           42308.65

# %%
category_df.plot.pie(subplots=True,autopct="%1.1f%%",legend=False,ylabel=" ",startangle=90)
plt.savefig("TFA_FRTbyC.png")
plt.title("Total Fiscal Amount of Fradulent Transactions by Category")
# Out:
# Text(0.5, 1.0, 'Total Fiscal Amount of Fradulent Transactions by Category')

# %%
category=pd.DataFrame(cc_data["category"].value_counts())
category
# Out:
#                 count
# category
# gas_transport    1042
# home              949
# grocery_pos       933
# shopping_pos      907
# kids_pets         863
# shopping_net      758
# food_dining       716
# entertainment     693
# misc_pos          670
# personal_care     665
# health_fitness    644
# misc_net          468
# grocery_net       379
# travel            313

# %%
category.plot(kind='pie',subplots=True,autopct="%1.1f%%",legend=False,ylabel=" ",startangle=90)
plt.savefig("Frq_FRTbyC.png")
plt.title("Frequency of Fradulent Transactions by Category")
# Out:
# Text(0.5, 1.0, 'Frequency of Fradulent Transactions by Category')

# %%
gender_plot=cc_data.hvplot.points("long","lat",geo=True,tiles="OSM",color="gender",hover_cols=["state","category"])
gender_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [long,lat]   (gender,state,category)

# %%
alaska_df=cc_data.loc[cc_data["state"]=="AK"]
alaska_df.head()
# Out:
#       Unnamed: 0 trans_date_trans_time       category    amt    city state  \
# 541       336425   2020-12-28 07:22:32   shopping_net   6.05   Wales    AK
# 1460      185003   2020-02-17 23:45:26  entertainment  39.57  Huslia    AK
# 1664      232812   2020-06-11 15:45:51  entertainment  77.05   Wales    AK
# 1666      216227   2020-05-07 08:11:24  gas_transport  43.74   Wales    AK
# 2014      251984   2020-07-18 16:42:44           home   3.67   Wales    AK
#
#           lat      long  city_pop         dob  merch_lat  merch_long gender  \
# 541   64.7556 -165.6723       145  1939-11-09  64.924942 -166.034386      M
# 1460  65.6899 -156.2920       277  1965-11-06  64.819398 -155.890378    NaN
# 1664  64.7556 -165.6723       145  1939-11-09  64.994862 -165.910617    NaN
# 1666  64.7556 -165.6723       145  1939-11-09  63.850908 -166.114254    NaN
# 2014  64.7556 -165.6723       145  1939-11-09  63.914713 -166.116436      M
#
#       trans_date trans_time hour min:sec
# 541   2020-12-28   07:22:32   07   22:32
# 1460  2020-02-17   23:45:26   23   45:26
# 1664  2020-06-11   15:45:51   15   45:51
# 1666  2020-05-07   08:11:24   08   11:24
# 2014  2020-07-18   16:42:44   16   42:44

# %%
alaska_plot=alaska_df.hvplot.points("long","lat",geo=True,tiles="OSM",color="gender",hover_cols=["state","category"])
alaska_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [long,lat]   (gender,state,category)

# %%
continental_df=cc_data.loc[cc_data["state"]!="HI"]
continental_df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time       category     amt         city state  \
# 0      471033   2020-08-16 23:34:52      kids_pets   31.93      Shields    ND
# 1       35353   2019-04-08 21:18:33           home   11.59    Daly City    CA
# 2      391141   2020-07-13 05:47:18    food_dining   37.97       Bailey    NC
# 3      369533   2020-07-04 03:59:39  gas_transport   58.38  Whaleyville    MD
# 4      767951   2020-12-25 03:43:30    grocery_pos  107.58        Utica    PA
#
#        lat      long  city_pop         dob  merch_lat  merch_long gender  \
# 0  46.1838 -101.2589        77  1989-12-17  45.455940 -100.470589      F
# 1  37.6787 -122.4780    107941  1991-10-04  36.716307 -122.974625    NaN
# 2  35.8072  -78.0892      6629  1962-08-13  36.530192  -78.072629      F
# 3  38.4121  -75.2811       718  1985-03-19  39.172607  -75.400129      F
# 4  41.4798  -79.9403      1102  1989-07-08  41.149434  -80.700821      M
#
#    trans_date trans_time hour min:sec
# 0  2020-08-16   23:34:52   23   34:52
# 1  2019-04-08   21:18:33   21   18:33
# 2  2020-07-13   05:47:18   05   47:18
# 3  2020-07-04   03:59:39   03   59:39
# 4  2020-12-25   03:43:30   03   43:30

# %%
continental_df_plot=continental_df.hvplot.points("long","lat",geo=True,tiles="OSM",color="gender",hover_cols=["state","category"])
continental_df_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [long,lat]   (gender,state,category)

# %%
contiguos_df=continental_df.loc[continental_df["state"]!="AK"]
contigous_plot=contiguos_df.hvplot.points("long","lat",geo=True,tiles="OSM",color="gender",hover_cols=["state","category"],title="Location of Fraud Victims by Gender")
plt.savefig("Victim_Location.png")
contigous_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [long,lat]   (gender,state,category)

# %%
contiguos_df=continental_df.loc[continental_df["state"]!="AK"]
contigous_plot=contiguos_df.hvplot.points("merch_long","merch_lat",geo=True,tiles="OSM",color="category",title="Location of Fraudulent Transactions by Category")
plt.savefig("Merchant_Location.png")
contigous_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [merch_long,merch_lat]   (category)

# %%
gender_dis=cc_data["gender"].value_counts()
gender_dis.plot.pie(autopct="%1.1f%%",title="Victim Distribution by Gender",explode={0,.08})
plt.savefig("Gender_Distribution.png")
plt.show()
