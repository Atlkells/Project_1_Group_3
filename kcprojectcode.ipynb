# %%
# setup
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read sample csv
cc_data = pd.read_csv(r"/Users/Kelly/Documents/Vanderbilt/data_analytics/Module 7/Project_1_Group_3/cc_data.csv")
cc_data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time       category     amt        city state  \
# 0      264421   2020-08-10 20:51:43           home   89.89    Issaquah    WA
# 1      142181   2019-11-27 03:24:33  gas_transport   94.68     Redford    MO
# 2       85904   2019-07-25 13:00:43         travel    6.58    Thompson    UT
# 3      283240   2020-09-20 02:26:52    grocery_pos  183.11    Meridian    ID
# 4      328015   2020-12-18 04:48:00    grocery_pos  103.79  Fiddletown    CA
#
#        lat      long  city_pop         dob  merch_lat  merch_long gender
# 0  47.4974 -122.0107     50489  1984-02-29  48.036797 -121.213440      F
# 1  37.3272  -91.0243       241  1974-10-27  36.598969  -90.665853    NaN
# 2  38.9999 -109.6150        46  1987-04-23  39.782704 -109.798283    NaN
# 3  43.6498 -116.4306     84106  1971-02-11  43.572589 -117.145660      F
# 4  38.5234 -120.6763       832  1987-05-19  39.110742 -120.716384      M

# %%
#Creating Trans Month Column
cc_data["trans_date_trans_time"] = pd.to_datetime(cc_data["trans_date_trans_time"])
cc_data['Trans Month'] = cc_data["trans_date_trans_time"].dt.month.astype(int)
cc_data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time       category     amt        city state  \
# 0      264421   2020-08-10 20:51:43           home   89.89    Issaquah    WA
# 1      142181   2019-11-27 03:24:33  gas_transport   94.68     Redford    MO
# 2       85904   2019-07-25 13:00:43         travel    6.58    Thompson    UT
# 3      283240   2020-09-20 02:26:52    grocery_pos  183.11    Meridian    ID
# 4      328015   2020-12-18 04:48:00    grocery_pos  103.79  Fiddletown    CA
#
#        lat      long  city_pop         dob  merch_lat  merch_long gender  \
# 0  47.4974 -122.0107     50489  1984-02-29  48.036797 -121.213440      F
# 1  37.3272  -91.0243       241  1974-10-27  36.598969  -90.665853    NaN
# 2  38.9999 -109.6150        46  1987-04-23  39.782704 -109.798283    NaN
# 3  43.6498 -116.4306     84106  1971-02-11  43.572589 -117.145660      F
# 4  38.5234 -120.6763       832  1987-05-19  39.110742 -120.716384      M
#
#    Trans Month
# 0            8
# 1           11
# 2            7
# 3            9
# 4           12

# %%
#Creating Trans Year Column
cc_data["trans_date_trans_time"] = pd.to_datetime(cc_data["trans_date_trans_time"])
cc_data['Trans Year'] = cc_data["trans_date_trans_time"].dt.year.astype(int)
cc_data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time       category     amt        city state  \
# 0      264421   2020-08-10 20:51:43           home   89.89    Issaquah    WA
# 1      142181   2019-11-27 03:24:33  gas_transport   94.68     Redford    MO
# 2       85904   2019-07-25 13:00:43         travel    6.58    Thompson    UT
# 3      283240   2020-09-20 02:26:52    grocery_pos  183.11    Meridian    ID
# 4      328015   2020-12-18 04:48:00    grocery_pos  103.79  Fiddletown    CA
#
#        lat      long  city_pop         dob  merch_lat  merch_long gender  \
# 0  47.4974 -122.0107     50489  1984-02-29  48.036797 -121.213440      F
# 1  37.3272  -91.0243       241  1974-10-27  36.598969  -90.665853    NaN
# 2  38.9999 -109.6150        46  1987-04-23  39.782704 -109.798283    NaN
# 3  43.6498 -116.4306     84106  1971-02-11  43.572589 -117.145660      F
# 4  38.5234 -120.6763       832  1987-05-19  39.110742 -120.716384      M
#
#    Trans Month  Trans Year
# 0            8        2020
# 1           11        2019
# 2            7        2019
# 3            9        2020
# 4           12        2020

# %%
# Group by 'Trans Month' and count the number of fraud transactions in each month
fraud_by_month = cc_data.groupby('Trans Month').size()
title = "Fraud Transactions Breakdown by Time of Day"
# Create a bar graph
fraud_by_month.plot(kind='bar', color='red', alpha=0.7)
plt.title(title)
plt.xlabel('Months')
plt.ylabel('Number of Fraud Transactions')
plt.xticks(rotation=0)  # Rotate x-axis labels for better visibility
plt.show()
